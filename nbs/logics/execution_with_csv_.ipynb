# %%
#%% Importing Libraries
import pandas as pd , numpy as np
pd.set_option('max_columns',200)
pd.set_option('max_rows',200)

import pickle , warnings
warnings.filterwarnings('ignore')

from scipy.optimize import minimize , Bounds , LinearConstraint , NonlinearConstraint

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# ### Media

# %%
def intial_manipulations(path , optimization = 0):
    
    #reading data
    df = pd.read_csv(path).round(2)
    
    # getting inputs from user
    total_grp = (df['input_weekly_grp'] * df['input_WOA']).max()
    total_spend = df['input_spends'].max()

    ####################################################################################################
    # for mat 3 min cons
    current_volume = 75.3e6 # database
    growth_ambition_perc = 0.1 ## user_input
    growth_ambition_volume = current_volume * growth_ambition_perc
    current_volume_contribution = (df['current_metric_value'] * df['current_effectiveness']).sum() 

    matrix_3_min_cons = growth_ambition_volume + current_volume_contribution
    ####################################################################################################
    
    df_only = df[df['genre_platform'] != 'Total']
    df_total = df[df['genre_platform'] == 'Total']
    
    if optimization == 1:
    
        def bounds_col(value , media_type , min_ = 0 , max_ = 0 , total_grp = 0 , total_spends = 0):

            if min_ != 0:
                if media_type == 'TV': return 0.2 * value
                if media_type == 'Digital': return 0.05 * value

            if max_ != 0:
                if media_type == 'TV': return 0.7 * total_grp
                if media_type == 'Digital': return (0.3 * total_spends) / value

        def cost(value_to_optimize , data  = df_only):  

            data['Recommended_val'] = value_to_optimize
            cal_values = list(map(lambda rv , mi, ma : True if mi <= rv <= ma else False , data['Recommended_val'] ,  data['lower_bounds'] ,  data['upper_bounds']))
            if all(cal_values): total_val = (data['input_cost_per_metric'] * (data['Recommended_val'] - data['current_metric_value'])).sum()
            else: total_val = 1e9

            return total_val

        # getting lower and upper bounds
        df_only['lower_bounds'] = tuple(map(lambda x , y : bounds_col(x,y , min_ = 1) , df_only['current_metric_value'] , df_only['media_type']))
        df_only['upper_bounds'] = tuple(map(lambda x , y : bounds_col(x,y , max_ = 1 , total_grp = total_grp , total_spends = total_spend) ,
                                       df_only['input_cost_per_metric'] , df_only['media_type']))

        # making contraint matrix
        df_only['matrix_row_1_tv'] = df_only['media_type'].apply(lambda x : 1 if x == 'TV' else 0)
        df_only['matrix_row_2_digital'] = df_only['media_type'].apply(lambda x : 1 if x == 'Digital' else 0)
        df_only['matrix_row_3_vg'] = df_only['current_effectiveness'].copy()

        # random start values
        df_only['start_values'] = list(map(lambda x , y : np.random.randint(x , y) , df_only['lower_bounds'] , df_only['upper_bounds'].replace(0 , 1)))

        # bounds and constraint
        bounds = Bounds( df_only['lower_bounds'] , df_only['upper_bounds'] , keep_feasible = False)
        cons_ = LinearConstraint(df_only.filter(regex = 'matrix').T.values , 
                                 [0, 0 , matrix_3_min_cons], [total_grp, total_spend, np.inf])


        # optimization
        optimize_output = minimize(cost , x0 = df_only['start_values'] , args = df_only ,
                                   bounds = bounds  ,  method = 'trust-constr' , constraints = cons_ ,
                                   hess = lambda x , data : np.zeros((x.shape[0], x.shape[0])) ,
                                   options = {'maxiter' : 1000 , 'disp' : True} )

    return locals()

# %%
all_data_mani = intial_manipulations(path = r"..\CSV Data as Input\media_records (1).csv" , optimization = 1)

all_data_mani.keys()

df_only = all_data_mani['df_only'].reset_index(drop = True)
df_total = all_data_mani['df_total'].reset_index(drop = True)
# Out:
# `xtol` termination condition is satisfied.
# Number of iterations: 184, function evaluations: 787, CG iterations: 172, optimality: 4.14e+02, constraint violation: 8.94e+07, execution time:  2.2 s.
# dict_keys(['path', 'optimization', 'df', 'current_volume', 'growth_ambition_perc', 'growth_ambition_volume', 'current_volume_contribution', 'matrix_3_min_cons', 'df_only', 'df_total', 'cost', 'bounds', 'cons_', 'optimize_output', 'bounds_col', 'total_grp', 'total_spend'])

# %%
def brand_level(_data , _total_data , val): 
    data_ = _data.copy()
    cols = ['country' , 'year' , 'timeline' , 'analysis_period' , 'category' , 'brand' , 'media_type']
    
    data_ = data_.drop('id',1).groupby(cols, sort = False).sum()
    _total_data[val] = data_.reset_index()[val]
    
    return data_

def spends_output(data , total_data ,try_ = 0):
    if try_ == 0: 
        data['Recommended_spends'] = data['Recommended_val'] * data['input_cost_per_metric']
        brand_level(data , total_data , 'Recommended_spends')
        
    if try_ == 1:
        data['Try_spends_output'] = data['Try_scenario_input'] * data['input_cost_per_metric'] # ask honey to provide impressions for digital
        brand_level(data , total_data , 'Try_spends_output')
        
def volume_contribution(data , total_data ,try_ = 0):
    if try_ == 0: 
        data['Recommended_vc'] = data['Recommended_val'] * data['current_effectiveness']
        brand_level(data , total_data , 'Recommended_vc')
        
    if try_ == 1: 
        data['Try_vc_output'] = tuple(map(lambda grp , eff , med , sp , cpm : grp * eff if me == 'TV'
                                          else (sp / cpm) * eff if med == 'Digital' else 0),
                                      data['Try_tv_grp'] , data['current_effectiveness'] ,data['media_type'] ,
                                      data['Try_scenerio_spends_digital'] , data['input_cost_per_metric'])
        brand_level(data , total_data , 'Try_vc_output')
        
def roi_output(data ,total_df ,  try_ = 0):
    if try_ == 0: 
        data['Recommended_roi'] = (data['Recommended_vc'] * data['current_ASP']) / data['Recommended_spends']
        
        # brand level roi
        data['Recommended_roi_brand'] = data['Recommended_roi'] * data['Recommended_spends']
        brand_level(data , total_df , 'Recommended_roi_brand')
        total_df['Recommended_roi_brand'] = total_df['Recommended_roi_brand'] / total_df['Recommended_spends']
        total_df.rename(columns = {'Recommended_roi_brand' : 'Recommended_roi'} , inplace = True)
        data.drop('Recommended_roi_brand' , 1 , inplace = True)
        
    if try_ == 1: 
        data['Try_roi_output'] = (data['Try_vc'] * data['current_ASP']) / data['Try_spends_output']
        
        data['Try_roi_brand_output'] = data['Try_roi_output'] * data['Try_spends_output']
        brand_level(data , total_df , 'Try_roi_brand_output')
        total_df['Try_roi_brand_output'] = total_df['Try_roi_brand_output'] / total_df['Try_spends_output']
        total_df.rename(columns = {'Try_roi_brand_output' : 'Try_roi_output'} , inplace = True)
        data.drop('Try_roi_brand_output' , 1 , inplace = True)

# %%
spends_output(df_only , df_total)
volume_contribution(df_only, df_total)
roi_output(df_only , df_total)

# %%
final_df = pd.concat([df_only , df_total])

# %%
final_df
# Out:
#     id country  year      timeline       analysis_period   category  brand  \
# 0    2     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 1    3     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 2    4     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 3    5     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 4    8     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 5    9     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 6   10     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 7   11     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 8   12     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 9   13     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 10  14     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 11  15     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 0    1     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
# 1    7     KSA  2021  MAT May 2021  Jan 2018 to May 2021  Beverages  Pepsi
#
#    media_type    genre_platform  current_spends  current_metric_value  \
# 0          TV     Entertainment        860376.0                  1456
# 1          TV       Sports Bein         78788.0                     0
# 2          TV   Sports Non-Bein        499090.0                  1332
# 3          TV   Movies & Series        601441.0                  1201
# 4     Digital       anghami.com             NaN                     0
# 5     Digital          Facebook        296127.0               4830586
# 6     Digital         Instagram        108441.0               1004215
# 7     Digital      Programmatic        144638.0               4227535
# 8     Digital  Resolution Media        192094.0               6017385
# 9     Digital          Snapchat        208919.0               1976612
# 10    Digital           YouTube        328587.0              45281154
# 11    Digital            TikTok        395996.0              10670259
# 0          TV             Total       1960907.0                  3989
# 1     Digital             Total       1674802.0              74007746
#
#     current_effectiveness  current_impressions  current_volume  current_ASP  \
# 0                   63.00                  NaN        91728.00            9
# 1                   71.00                  NaN            0.00            9
# 2                  195.00                  NaN       259740.00            9
# 3                  136.00                  NaN       163336.00            9
# 4                    0.07                  NaN            0.00            9
# 5                    0.02                  NaN        77289.38            9
# 6                    0.02                  NaN        18075.87            9
# 7                    0.02                  NaN        80323.16            9
# 8                    0.11                  NaN       631825.43            9
# 9                    0.00                  NaN         7906.45            9
# 10                   0.02                  NaN       815060.77            9
# 11                   0.02                  NaN       245415.96            9
# 0                  129.00                  NaN       514581.00            9
# 1                    0.03                  NaN      1850193.65            9
#
#     current_revenue  current_ROI  input_cost_per_metric  input_weekly_grp  \
# 0         837093.28          1.0                 591.00               NaN
# 1              0.00          NaN                  73.00               NaN
# 2        2370340.66          4.7                 375.00               NaN
# 3        1490575.04          2.5                 501.00               NaN
# 4              0.00          NaN                   0.25               NaN
# 5         705328.98          2.4                   0.06               NaN
# 6         164957.15          1.5                   0.11               NaN
# 7         733014.80          5.1                   0.03               NaN
# 8        5765925.52         30.0                   0.03               NaN
# 9          72152.83          0.3                   0.11               NaN
# 10       7438098.43         22.6                   0.01               NaN
# 11       2239622.01          5.7                   0.04               NaN
# 0        4695973.92          2.4                 491.00             480.0
# 1       16884535.43         10.1                   0.02               NaN
#
#     input_WOA  input_spends  input_operating_point      metric_type currency  \
# 0         NaN           NaN                    NaN              grp      usd
# 1         NaN           NaN                    NaN              grp      usd
# 2         NaN           NaN                    NaN              grp      usd
# 3         NaN           NaN                    NaN              grp      usd
# 4         NaN           NaN                    NaN  Completed Views      usd
# 5         NaN           NaN                    NaN  Completed Views      usd
# 6         NaN           NaN                    NaN  Completed Views      usd
# 7         NaN           NaN                    NaN  Completed Views      usd
# 8         NaN           NaN                    NaN  Completed Views      usd
# 9         NaN           NaN                    NaN  Completed Views      usd
# 10        NaN           NaN                    NaN  Completed Views      usd
# 11        NaN           NaN                    NaN  Completed Views      usd
# 0        50.0           NaN                  250.0              grp      usd
# 1         NaN     2500000.0                    NaN  Completed Views      usd
#
#     spends_divisor  lower_bounds  upper_bounds  matrix_row_1_tv  \
# 0             1000        291.20  1.680000e+04              1.0
# 1             1000          0.00  1.680000e+04              1.0
# 2             1000        266.40  1.680000e+04              1.0
# 3             1000        240.20  1.680000e+04              1.0
# 4             1000          0.00  3.000000e+06              0.0
# 5             1000     241529.30  1.250000e+07              0.0
# 6             1000      50210.75  6.818182e+06              0.0
# 7             1000     211376.75  2.500000e+07              0.0
# 8             1000     300869.25  2.500000e+07              0.0
# 9             1000      98830.60  6.818182e+06              0.0
# 10            1000    2264057.70  7.500000e+07              0.0
# 11            1000     533512.95  1.875000e+07              0.0
# 0             1000           NaN           NaN              NaN
# 1             1000           NaN           NaN              NaN
#
#     matrix_row_2_digital  matrix_row_3_vg  start_values  Recommended_val  \
# 0                    0.0            63.00        1200.0     2.912000e+02
# 1                    0.0            71.00       15156.0     1.543502e+04
# 2                    0.0           195.00       15348.0     1.572393e+04
# 3                    0.0           136.00        9662.0     9.398945e+03
# 4                    1.0             0.07      937336.0     9.371938e+05
# 5                    1.0             0.02     7069503.0     7.069361e+06
# 6                    1.0             0.02     1255888.0     1.255746e+06
# 7                    1.0             0.02    12378271.0     1.237813e+07
# 8                    1.0             0.11    18373145.0     1.837300e+07
# 9                    1.0             0.00     1615791.0     1.615649e+06
# 10                   1.0             0.02    47686570.0     4.768643e+07
# 11                   1.0             0.02     2539977.0     2.539835e+06
# 0                    NaN              NaN           NaN              NaN
# 1                    NaN              NaN           NaN              NaN
#
#     Recommended_spends  Recommended_vc  Recommended_roi
# 0         1.720992e+05    1.834560e+04         0.959391
# 1         1.126756e+06    1.095886e+06         8.753425
# 2         5.896475e+06    3.066167e+06         4.680000
# 3         4.708871e+06    1.278257e+06         2.443114
# 4         2.342985e+05    6.560357e+04         2.520000
# 5         4.241617e+05    1.413872e+05         3.000000
# 6         1.381320e+05    2.511492e+04         1.636364
# 7         3.713439e+05    2.475626e+05         6.000000
# 8         5.511901e+05    2.021030e+06        33.000000
# 9         1.777214e+05    0.000000e+00         0.000000
# 10        4.768643e+05    9.537286e+05        18.000000
# 11        1.015934e+05    5.079670e+04         4.500000
# 0         1.190420e+07    5.458655e+06         4.126938
# 1         2.475305e+06    3.505224e+06        12.744697

# %% [markdown]
# ### Distribution

# %%
recommended_volume_contribution = (final_df['Recommended_val'] * final_df['current_effectiveness']).sum()

current_volume = 75.3e6 # database
growth_ambition_perc = 0.1 ## user_input
growth_ambition_volume = current_volume * growth_ambition_perc
current_volume_contribution = (final_df['current_metric_value'] * final_df['current_effectiveness']).sum() 

achieved_from_media = recommended_volume_contribution - current_volume_contribution

# %%
# current_volume = 75.3e6 # database
# growth_ambition_perc = 0.1 ## user_input
# growth_ambition_volume = current_volume*growth_ambition_perc

remainder_volume_growth =  growth_ambition_volume - achieved_from_media # 124

# %%
# data manipulation
df_dist = pd.read_excel(r"..\CSV Data as Input\KSA Pepsi Distribution.xlsx" )

dfs, lever, current_val = [] , ['price' , 'distribution' , 'trade'] , ['current_price_per_pack', 'current_distribution', 'current_trade']
for lev , cv in zip(lever , current_val):
    op = df_dist[['id','current_volume','current_price_per_volume', cv, lev+'_elasticity','channel']].rename(columns = {cv : 'current_val' , lev + '_elasticity' : 'elasticity'}).dropna()
    op['lever'] = lev
    dfs.append(op)    

df_dist_analysis = pd.concat(dfs).reset_index(drop = True)

def volume_growth(data, return_sum = False , try_ = 0):
    if try_ == 0: pct_change_lever = (data['Recommended_val'] / data['current_val']) - 1
    if try_ == 1: pct_change_lever = (data['Try_input'] / data['current_val']) - 1
    pct_change_volume = pct_change_lever * data['elasticity']
    vg = pct_change_volume * data['current_volume']
    if return_sum: return sum(vg)
    return vg

def volume_constraint(x , data = df_dist_analysis.copy()):
    data['Recommended_val'] = x
    vg = volume_growth(data, return_sum=True)
    return vg

def cost_of_distribution(data):
    cost = 0.01 * (data['Recommended_val'] - data['current_val'])
    return sum(cost)

def cost_of_price(data):
    vg = volume_growth(data)
    cost = vg * (data['Recommended_val'] - data['current_val'])
    return sum(cost)

def cost_of_trade(data):
    vg = volume_growth(data)
    cost = vg * (data['Recommended_val'] - data['current_val']) * data['current_price_per_volume']
    return sum(cost)

def cost(values_to_optimize , data):
    
    data['Recommended_val'] = values_to_optimize
    cal_values = list(map(lambda rv , mi, ma : True if mi <= rv <= ma else False , data['Recommended_val'] ,  data['lower_bounds'] ,  data['upper_bounds']))
    
    if all(cal_values):
        
        p = cost_of_price(data[data['lever'] == 'price'])
        d = cost_of_distribution(data[data['lever'] == 'distribution'])
        t = cost_of_trade(data[data['lever'] == 'trade'])
    
        total_val = p + d + t
        return total_val
       
    else: 
        total_val = 1e9

    return total_val

# Bounds
B = 0.10
df_dist_analysis['lower_bounds'] = df_dist_analysis['current_val'] * (1 - B)
df_dist_analysis['upper_bounds'] = df_dist_analysis['current_val'] * (1 + B)

bounds = Bounds(lb = df_dist_analysis['lower_bounds'], ub = df_dist_analysis['upper_bounds'], keep_feasible = False)

nl_constraints = NonlinearConstraint(volume_constraint,
                                     lb = remainder_volume_growth ,
                                     ub = np.inf, 
                                     keep_feasible = False)

df_dist_analysis['start_values'] = list(map(lambda x , y : np.arange(x,y,0.01)[np.random.randint(len(np.arange(x,y,0.01)))] ,
                                            df_dist_analysis['lower_bounds'] , df_dist_analysis['upper_bounds']))

iterations = 2#int(1e3)

# %%
result = minimize(cost , x0 = df_dist_analysis['start_values'] , args = df_dist_analysis, 
                  bounds = bounds , constraints = [nl_constraints] , hess = lambda x , data : np.zeros((x.shape[0], x.shape[0])),
                  method = 'trust-constr' , 
                  options = {'maxiter': iterations, 'verbose': 1, 'factorization_method':'SVDFactorization'})
                  
print(result.success, result.cg_stop_cond)


def try_sc(data , try_ = 0):
    if try_sc == 1: out = volume_growth(data , try_ = 1)
    return vg

def out(lv , val):
    if lv == 'price': return (val , np.nan , np.nan)
    if lv == 'distribution': return (np.nan, val , np.nan)
    if lv == 'trade': return (np.nan , np.nan , val)
# Out:
# The maximum number of function evaluations is exceeded.
# Number of iterations: 2, function evaluations: 80, CG iterations: 1, optimality: 1.96e+06, constraint violation: 2.20e+06, execution time: 0.16 s.
# False 2

# %%
new_names = ['Recommended_' + i.replace('current_','') for i in current_val]
df_dist_analysis[new_names] = tuple(map(
    lambda lv , val : out(lv ,val) , df_dist_analysis['lever'] , df_dist_analysis['Recommended_val'] ))

df_dist_analysis.drop(columns = ['Recommended_val',], inplace = True)

# %%
df_dist_analysis
# Out:
# 40  Traditional Trade         price      2.496679      3.051497      3.026679
# 41  Traditional Trade         price      4.501019      5.501245      5.421019
# 42  Traditional Trade         price      8.099650      9.899572      8.939650
# 43  Traditional Trade         price      8.098897      9.898652      8.498897
# 44           Eateries  distribution      0.613567      0.749916      0.663567
# 45           Eateries  distribution      0.334309      0.408600      0.364309
# 46           Eateries  distribution      1.291271      1.578220      1.291271
# 47           Eateries  distribution      8.808274     10.765668      9.628274
# 48           Eateries  distribution      0.284470      0.347685      0.344470
# 49           Eateries  distribution      0.885744      1.082577      0.935744
# 50           Eateries  distribution      0.076696      0.093739      0.076696
# 51           Eateries  distribution      1.927419      2.355735      2.037419
# 52           Eateries  distribution      1.928756      2.357368      2.278756
# 53           Eateries  distribution      1.245975      1.522858      1.285975
# 54           Eateries  distribution      4.957710      6.059424      6.017710
# 55       Self Service  distribution     31.313880     38.272520     36.353880
# 56       Self Service  distribution     16.047360     19.613440     16.157360
# 57       Self Service  distribution     47.880450     58.520550     48.040450
# 58       Self Service  distribution     75.428100     92.189900     82.028100
# 59       Self Service  distribution      9.291780     11.356620      9.601780
# 60       Self Service  distribution     10.860390     13.273810     11.310390
# 61       Self Service  distribution      8.967060     10.959740      9.817060
# 62       Self Service  distribution      3.508290      4.287910      3.708290
# 63       Self Service  distribution     82.407690    100.720510     95.487690
# 64       Self Service  distribution     28.874700     35.291300     33.034700
# 65       Self Service  distribution     83.096640    101.562560     89.136640
# 66  Traditional Trade  distribution     30.169260     36.873540     31.139260
# 67  Traditional Trade  distribution      8.509950     10.401050      9.309950
# 68  Traditional Trade  distribution     65.190150     79.676850     78.800150
# 69  Traditional Trade  distribution    168.043770    205.386830    176.193770
# 70  Traditional Trade  distribution      7.532820      9.206780      8.802820
# 71  Traditional Trade  distribution     10.053450     12.287550     11.703450
# 72  Traditional Trade  distribution      2.563380      3.133020      3.003380
# 73  Traditional Trade  distribution      5.680350      6.942650      6.740350
# 74  Traditional Trade  distribution     82.025370    100.253230     83.635370
# 75  Traditional Trade  distribution     51.281910     62.677890     60.661910
# 76  Traditional Trade  distribution     75.940830     92.816570     76.530830
# 77  Traditional Trade         trade      0.042794      0.052303      0.042794
#
#     Recommended_price_per_pack  Recommended_distribution  Recommended_trade
# 0                     1.892064                       NaN                NaN
# 1                     4.201009                       NaN                NaN
# 2                     1.848393                       NaN                NaN
# 3                     2.654598                       NaN                NaN
# 4                    17.046081                       NaN                NaN
# 5                     8.493064                       NaN                NaN
# 6                     3.317001                       NaN                NaN
# 7                     3.646933                       NaN                NaN
# 8                     4.767574                       NaN                NaN
# 9                     8.890925                       NaN                NaN
# 10                    7.608443                       NaN                NaN
# 11                    1.869192                       NaN                NaN
# 12                    1.831829                       NaN                NaN
# 13                    2.028666                       NaN                NaN
# 14                    2.550237                       NaN                NaN
# 15                    2.288701                       NaN                NaN
# 16                    2.802816                       NaN                NaN
# 17                    2.716013                       NaN                NaN
# 18                    3.205203                       NaN                NaN
# 19                    5.056034                       NaN                NaN
# 20                    8.747072                       NaN                NaN
# 21                    9.163644                       NaN                NaN
# 22                    1.972485                       NaN                NaN
# 23                    1.925452                       NaN                NaN
# 24                    1.859827                       NaN                NaN
# 25                    2.629717                       NaN                NaN
# 26                    3.254032                       NaN                NaN
# 27                    2.758123                       NaN                NaN
# 28                    3.018261                       NaN                NaN
# 29                    3.521714                       NaN                NaN
# 30                    4.671684                       NaN                NaN
# 31                    8.198555                       NaN                NaN
# 32                    8.409283                       NaN                NaN
# 33                    1.889971                       NaN                NaN
# 34                    2.015412                       NaN                NaN
# 35                    1.981077                       NaN                NaN
# 36                    2.443780                       NaN                NaN
# 37                    2.685439                       NaN                NaN
# 38                    2.485840                       NaN                NaN
# 39                    2.649322                       NaN                NaN
# 40                    3.011734                       NaN                NaN
# 41                    5.394422                       NaN                NaN
# 42                    8.942826                       NaN                NaN
# 43                    8.433597                       NaN                NaN
# 44                         NaN                  0.641984                NaN
# 45                         NaN                  0.350026                NaN
# 46                         NaN                  1.284151                NaN
# 47                         NaN                  9.615396                NaN
# 48                         NaN                  0.330267                NaN
# 49                         NaN                  0.834837                NaN
# 50                         NaN                 -0.180650                NaN
# 51                         NaN                  2.021467                NaN
# 52                         NaN                  2.254449                NaN
# 53                         NaN                  1.288599                NaN
# 54                         NaN                  5.945325                NaN
# 55                         NaN                 36.347294                NaN
# 56                         NaN                 16.197344                NaN
# 57                         NaN                 48.080765                NaN
# 58                         NaN                 82.029148                NaN
# 59                         NaN                  9.627776                NaN
# 60                         NaN                 11.330438                NaN
# 61                         NaN                  9.820276                NaN
# 62                         NaN                  3.720812                NaN
# 63                         NaN                 95.484312                NaN
# 64                         NaN                 33.030674                NaN
# 65                         NaN                 89.138362                NaN
# 66                         NaN                 31.151106                NaN
# 67                         NaN                  9.312597                NaN
# 68                         NaN                 78.784583                NaN
# 69                         NaN                176.195498                NaN
# 70                         NaN                  8.784380                NaN
# 71                         NaN                 11.688873                NaN
# 72                         NaN                  2.992152                NaN
# 73                         NaN                  6.716013                NaN
# 74                         NaN                 83.644602                NaN
# 75                         NaN                 60.654220                NaN
# 76                         NaN                 76.550438                NaN
# 77                         NaN                       NaN           0.208873

# %%
merge_cols = ['id','channel','current_volume','current_price_per_volume']

# %%
len(df_dist)
len(df_dist_analysis)
# Out:
# 48
# 78

# %%
final_exec = pd.merge(df_dist, df_dist_analysis[new_names + ['id','current_volume','current_price_per_volume']] ,
                      on = ['id','current_volume','current_price_per_volume'] , how = 'inner')

# %%
len(final_exec)
# Out:
# 78

# %%
final_exec
# Out:
#     id country            channel current_metrics_time current_volume_time  \
# 0    1     KSA        Supermarket           2021-05-01             CY 2020
# 1    2     KSA        Supermarket           2021-05-01             CY 2020
# 2    3     KSA        Supermarket           2021-05-01             CY 2020
# 3    4     KSA        Supermarket           2021-05-01             CY 2020
# 4    5     KSA        Supermarket           2021-05-01             CY 2020
# 5    6     KSA        Supermarket           2021-05-01             CY 2020
# 6    7     KSA        Supermarket           2021-05-01             CY 2020
# 7    8     KSA        Supermarket           2021-05-01             CY 2020
# 8    9     KSA        Supermarket           2021-05-01             CY 2020
# 9   10     KSA        Supermarket           2021-05-01             CY 2020
# 10  11     KSA        Supermarket           2021-05-01             CY 2020
# 66  42     KSA  Traditional Trade           2021-05-01             CY 2020
# 67  43     KSA  Traditional Trade           2021-05-01             CY 2020
# 68  43     KSA  Traditional Trade           2021-05-01             CY 2020
# 69  44     KSA  Traditional Trade           2021-05-01             CY 2020
# 70  44     KSA  Traditional Trade           2021-05-01             CY 2020
# 71  45     KSA  Traditional Trade           2021-05-01             CY 2020
# 72  45     KSA  Traditional Trade           2021-05-01             CY 2020
# 73  46     KSA  Traditional Trade           2021-05-01             CY 2020
# 74  46     KSA  Traditional Trade           2021-05-01             CY 2020
# 75  47     KSA  Traditional Trade           2021-05-01             CY 2020
# 76  47     KSA  Traditional Trade           2021-05-01             CY 2020
# 77  48     KSA  Traditional Trade           2021-05-01             CY 2020
#
#          analysis_period  category  brand currency volume_unit     pack_name  \
# 0   Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 240ML
# 1   Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 245ML
# 2   Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 250ML
# 3   Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 320ML
# 4   Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 325ML
# 5   Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 330ML
# 6   Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 355ML
# 7   Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 360ML
# 8   Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     MSPET  1L
# 9   Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case   MSPET  2.2L
# 10  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case  MSPET  2.25L
# 11  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 240ML
# 12  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 240ML
# 13  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 245ML
# 14  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 245ML
# 15  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 250ML
# 16  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 250ML
# 17  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 320ML
# 18  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 320ML
# 19  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 325ML
# 20  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 325ML
# 21  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 330ML
# 22  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 330ML
# 23  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 355ML
# 24  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 355ML
# 25  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 360ML
# 26  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 360ML
# 27  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     MSPET  1L
# 28  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     MSPET  1L
# 29  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case   MSPET  2.2L
# 30  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case   MSPET  2.2L
# 31  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case  MSPET  2.25L
# 32  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case  MSPET  2.25L
# 33  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 240ML
# 34  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 240ML
# 35  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 245ML
# 36  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 245ML
# 37  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 250ML
# 38  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 250ML
# 39  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 320ML
# 40  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 320ML
# 41  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 325ML
# 42  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 325ML
# 43  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 330ML
# 44  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 330ML
# 45  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 355ML
# 46  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 355ML
# 47  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 360ML
# 48  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 360ML
# 49  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     MSPET  1L
# 50  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     MSPET  1L
# 51  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case   MSPET  2.2L
# 52  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case   MSPET  2.2L
# 53  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case  MSPET  2.25L
# 54  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case  MSPET  2.25L
# 55  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 240ML
# 56  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 240ML
# 57  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 245ML
# 58  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 245ML
# 59  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 250ML
# 60  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 250ML
# 61  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 320ML
# 62  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 320ML
# 63  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 325ML
# 64  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 325ML
# 65  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 330ML
# 66  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 330ML
# 67  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 355ML
# 68  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 355ML
# 69  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 360ML
# 70  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     CAN 360ML
# 71  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     MSPET  1L
# 72  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case     MSPET  1L
# 73  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case   MSPET  2.2L
# 74  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case   MSPET  2.2L
# 75  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case  MSPET  2.25L
# 76  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case  MSPET  2.25L
# 77  Jan 2018 to May 2021  Beverage  Pepsi      SAR    8Oz case         Total
#
#     current_volume  price_elasticity  current_price_per_volume  \
# 0            30549         -7.920279                 42.228524
# 1             1494         -7.920279                 44.021514
# 2            57298         -7.920279                 45.388873
# 3           128232         -0.807162                 44.191023
# 4           946158         -0.807162                 39.375545
# 5          1205094         -0.807162                 39.628811
# 6          1692112         -0.807162                 42.902077
# 7            30895         -0.807162                 47.300982
# 8           939269         -0.997443                 25.682033
# 9          2026107         -1.677083                 18.939836
# 10         2161671         -1.677083                 20.004473
# 11          904861         -0.065713                 47.314827
# 12          904861         -0.065713                 47.314827
# 13          319615         -0.065713                 46.350008
# 14          319615         -0.065713                 46.350008
# 15         1385136         -0.065713                 45.423639
# 16         1385136         -0.065713                 45.423639
# 17         6524479         -0.619912                 44.343157
# 18         6524479         -0.619912                 44.343157
# 19          242691         -0.619912                 43.755147
# 20          242691         -0.619912                 43.755147
# 21         6370102         -0.619912                 43.944822
# 22         6370102         -0.619912                 43.944822
# 23         1369764         -0.619912                 40.153967
# 24         1369764         -0.619912                 40.153967
# 25         3029675         -0.619912                 47.312532
# 26         3029675         -0.619912                 47.312532
# 27         1976326          0.000000                 28.389700
# 28         1976326          0.000000                 28.389700
# 29          299605         -0.193184                 23.228261
# 30          299605         -0.193184                 23.228261
# 31         9878957         -0.193184                 22.711783
# 32         9878957         -0.193184                 22.711783
# 33          374944         -0.310689                 47.314972
# 34          374944         -0.310689                 47.314972
# 35          155988         -0.310689                 46.351912
# 36          155988         -0.310689                 46.351912
# 37          431523         -0.310689                 45.425772
# 38          431523         -0.310689                 45.425772
# 39         1350385         -0.653877                 44.358134
# 40         1350385         -0.653877                 44.358134
# 41           70090         -0.653877                 42.259846
# 42           70090         -0.653877                 42.259846
# 43         1620604         -0.653877                 27.515757
# 44         1620604         -0.653877                 27.515757
# 45          533842         -0.653877                 45.407021
# 46          533842         -0.653877                 45.407021
# 47           15227         -0.653877                 52.605942
# 48           15227         -0.653877                 52.605942
# 49         1342710         -0.040416                 28.489036
# 50         1342710         -0.040416                 28.489036
# 51          277393         -0.142290                 22.716727
# 52          277393         -0.142290                 22.716727
# 53         5074317         -0.142290                 22.762275
# 54         5074317         -0.142290                 22.762275
# 55          578414        -10.991712                 47.348104
# 56          578414        -10.991712                 47.348104
# 57          246345        -10.991712                 46.350284
# 58          246345        -10.991712                 46.350284
# 59         1118336        -10.991712                 45.459715
# 60         1118336        -10.991712                 45.459715
# 61         2978908         -3.907624                 44.357361
# 62         2978908         -3.907624                 44.357361
# 63          176600         -3.907624                 43.675493
# 64          176600         -3.907624                 43.675493
# 65         3256241         -3.907624                 43.261374
# 66         3256241         -3.907624                 43.261374
# 67          686060         -3.907624                 43.178818
# 68          686060         -3.907624                 43.178818
# 69           35295         -3.907624                 43.755533
# 70           35295         -3.907624                 43.755533
# 71         2970959          0.000000                 28.396171
# 72         2970959          0.000000                 28.396171
# 73          997850         -1.699106                 23.227203
# 74          997850         -1.699106                 23.227203
# 75         9502406         -1.699106                 22.708695
# 76         9502406         -1.699106                 22.708695
# 77        22547413               NaN                 32.148220
#
#     current_price_per_pack  current_volume_per_pack distribution_type  \
# 0                 1.784986                 0.042270               NaN
# 1                 4.396876                 0.099880               NaN
# 2                 1.998466                 0.044030               NaN
# 3                 2.845964                 0.064401               NaN
# 4                16.177799                 0.410859               NaN
# 5                 9.029592                 0.227854               NaN
# 6                 3.053779                 0.071180               NaN
# 7                 3.899114                 0.082432               NaN
# 8                 4.645755                 0.180895               NaN
# 9                 8.345761                 0.440646               NaN
# 10                7.928208                 0.396322               NaN
# 11                1.999997                 0.042270               FSS
# 12                1.999997                 0.042270               FSS
# 13                2.000002                 0.043150               FSS
# 14                2.000002                 0.043150               FSS
# 15                2.000002                 0.044030               FSS
# 16                2.000002                 0.044030               FSS
# 17                2.499180                 0.056360               FSS
# 18                2.499180                 0.056360               FSS
# 19                2.504541                 0.057240               FSS
# 20                2.504541                 0.057240               FSS
# 21                2.554070                 0.058120               FSS
# 22                2.554070                 0.058120               FSS
# 23                2.510460                 0.062521               FSS
# 24                2.510460                 0.062521               FSS
# 25                2.999615                 0.063400               FSS
# 26                2.999615                 0.063400               FSS
# 27                4.999995                 0.176120               FSS
# 28                4.999995                 0.176120               FSS
# 29                9.000023                 0.387460               FSS
# 30                9.000023                 0.387460               FSS
# 31                8.999999                 0.396270               FSS
# 32                8.999999                 0.396270               FSS
# 33                2.000004                 0.042270                WD
# 34                2.000004                 0.042270                WD
# 35                2.000083                 0.043150                WD
# 36                2.000083                 0.043150                WD
# 37                2.000103                 0.044030                WD
# 38                2.000103                 0.044030                WD
# 39                2.500024                 0.056360                WD
# 40                2.500024                 0.056360                WD
# 41                3.094321                 0.073221                WD
# 42                3.094321                 0.073221                WD
# 43                2.963273                 0.107694                WD
# 44                2.963273                 0.107694                WD
# 45                3.039581                 0.066941                WD
# 46                3.039581                 0.066941                WD
# 47                3.338416                 0.063461                WD
# 48                3.338416                 0.063461                WD
# 49                5.041175                 0.176951                WD
# 50                5.041175                 0.176951                WD
# 51                8.801827                 0.387460                WD
# 52                8.801827                 0.387460                WD
# 53                9.020006                 0.396270                WD
# 54                9.020006                 0.396270                WD
# 55                2.001403                 0.042270               TDP
# 56                2.001403                 0.042270               TDP
# 57                2.000007                 0.043150               TDP
# 58                2.000007                 0.043150               TDP
# 59                2.001593                 0.044030               TDP
# 60                2.001593                 0.044030               TDP
# 61                2.499981                 0.056360               TDP
# 62                2.499981                 0.056360               TDP
# 63                2.499982                 0.057240               TDP
# 64                2.499982                 0.057240               TDP
# 65                2.514373                 0.058121               TDP
# 66                2.514373                 0.058121               TDP
# 67                2.699515                 0.062519               TDP
# 68                2.699515                 0.062519               TDP
# 69                2.774088                 0.063400               TDP
# 70                2.774088                 0.063400               TDP
# 71                5.001132                 0.176120               TDP
# 72                5.001132                 0.176120               TDP
# 73                8.999611                 0.387460               TDP
# 74                8.999611                 0.387460               TDP
# 75                8.998774                 0.396270               TDP
# 76                8.998774                 0.396270               TDP
# 77                     NaN                      NaN               NaN
#
#     current_distribution  distribution_elasticity  current_trade  \
# 0                    NaN                      NaN            NaN
# 1                    NaN                      NaN            NaN
# 2                    NaN                      NaN            NaN
# 3                    NaN                      NaN            NaN
# 4                    NaN                      NaN            NaN
# 5                    NaN                      NaN            NaN
# 6                    NaN                      NaN            NaN
# 7                    NaN                      NaN            NaN
# 8                    NaN                      NaN            NaN
# 9                    NaN                      NaN            NaN
# 10                   NaN                      NaN            NaN
# 11              0.681742                 1.515821            NaN
# 12              0.681742                 1.515821            NaN
# 13              0.371454                 1.515821            NaN
# 14              0.371454                 1.515821            NaN
# 15              1.434745                 1.515821            NaN
# 16              1.434745                 1.515821            NaN
# 17              9.786971                 1.419040            NaN
# 18              9.786971                 1.419040            NaN
# 19              0.316077                 1.419040            NaN
# 20              0.316077                 1.419040            NaN
# 21              0.984160                 1.419040            NaN
# 22              0.984160                 1.419040            NaN
# 23              0.085218                 1.419040            NaN
# 24              0.085218                 1.419040            NaN
# 25              2.141577                 1.419040            NaN
# 26              2.141577                 1.419040            NaN
# 27              2.143062                 1.459513            NaN
# 28              2.143062                 1.459513            NaN
# 29              1.384416                 1.578502            NaN
# 30              1.384416                 1.578502            NaN
# 31              5.508567                 1.578502            NaN
# 32              5.508567                 1.578502            NaN
# 33             34.793200                 1.015766            NaN
# 34             34.793200                 1.015766            NaN
# 35             17.830400                 1.015766            NaN
# 36             17.830400                 1.015766            NaN
# 37             53.200500                 1.015766            NaN
# 38             53.200500                 1.015766            NaN
# 39             83.809000                 0.180911            NaN
# 40             83.809000                 0.180911            NaN
# 41             10.324200                 0.180911            NaN
# 42             10.324200                 0.180911            NaN
# 43             12.067100                 0.180911            NaN
# 44             12.067100                 0.180911            NaN
# 45              9.963400                 0.180911            NaN
# 46              9.963400                 0.180911            NaN
# 47              3.898100                 0.180911            NaN
# 48              3.898100                 0.180911            NaN
# 49             91.564100                 1.739826            NaN
# 50             91.564100                 1.739826            NaN
# 51             32.083000                 0.062785            NaN
# 52             32.083000                 0.062785            NaN
# 53             92.329600                 0.062785            NaN
# 54             92.329600                 0.062785            NaN
# 55             33.521400                 2.034923            NaN
# 56             33.521400                 2.034923            NaN
# 57              9.455500                 2.034923            NaN
# 58              9.455500                 2.034923            NaN
# 59             72.433500                 2.034923            NaN
# 60             72.433500                 2.034923            NaN
# 61            186.715300                 0.357306            NaN
# 62            186.715300                 0.357306            NaN
# 63              8.369800                 0.357306            NaN
# 64              8.369800                 0.357306            NaN
# 65             11.170500                 0.357306            NaN
# 66             11.170500                 0.357306            NaN
# 67              2.848200                 0.357306            NaN
# 68              2.848200                 0.357306            NaN
# 69              6.311500                 0.357306            NaN
# 70              6.311500                 0.357306            NaN
# 71             91.139300                 1.297495            NaN
# 72             91.139300                 1.297495            NaN
# 73             56.979900                 0.000000            NaN
# 74             56.979900                 0.000000            NaN
# 75             84.378700                 0.000000            NaN
# 76             84.378700                 0.000000            NaN
# 77                   NaN                      NaN       0.047549
#
#     trade_elasticity  Recommended_price_per_pack  Recommended_distribution  \
# 0                NaN                    1.892064                       NaN
# 1                NaN                    4.201009                       NaN
# 2                NaN                    1.848393                       NaN
# 3                NaN                    2.654598                       NaN
# 4                NaN                   17.046081                       NaN
# 5                NaN                    8.493064                       NaN
# 6                NaN                    3.317001                       NaN
# 7                NaN                    3.646933                       NaN
# 8                NaN                    4.767574                       NaN
# 9                NaN                    8.890925                       NaN
# 10               NaN                    7.608443                       NaN
# 11               NaN                    1.869192                       NaN
# 12               NaN                         NaN                  0.641984
# 13               NaN                    1.831829                       NaN
# 14               NaN                         NaN                  0.350026
# 15               NaN                    2.028666                       NaN
# 16               NaN                         NaN                  1.284151
# 17               NaN                    2.550237                       NaN
# 18               NaN                         NaN                  9.615396
# 19               NaN                    2.288701                       NaN
# 20               NaN                         NaN                  0.330267
# 21               NaN                    2.802816                       NaN
# 22               NaN                         NaN                  0.834837
# 23               NaN                    2.716013                       NaN
# 24               NaN                         NaN                 -0.180650
# 25               NaN                    3.205203                       NaN
# 26               NaN                         NaN                  2.021467
# 27               NaN                    5.056034                       NaN
# 28               NaN                         NaN                  2.254449
# 29               NaN                    8.747072                       NaN
# 30               NaN                         NaN                  1.288599
# 31               NaN                    9.163644                       NaN
# 32               NaN                         NaN                  5.945325
# 33               NaN                    1.972485                       NaN
# 34               NaN                         NaN                 36.347294
# 35               NaN                    1.925452                       NaN
# 36               NaN                         NaN                 16.197344
# 37               NaN                    1.859827                       NaN
# 38               NaN                         NaN                 48.080765
# 39               NaN                    2.629717                       NaN
# 40               NaN                         NaN                 82.029148
# 41               NaN                    3.254032                       NaN
# 42               NaN                         NaN                  9.627776
# 43               NaN                    2.758123                       NaN
# 44               NaN                         NaN                 11.330438
# 45               NaN                    3.018261                       NaN
# 46               NaN                         NaN                  9.820276
# 47               NaN                    3.521714                       NaN
# 48               NaN                         NaN                  3.720812
# 49               NaN                    4.671684                       NaN
# 50               NaN                         NaN                 95.484312
# 51               NaN                    8.198555                       NaN
# 52               NaN                         NaN                 33.030674
# 53               NaN                    8.409283                       NaN
# 54               NaN                         NaN                 89.138362
# 55               NaN                    1.889971                       NaN
# 56               NaN                         NaN                 31.151106
# 57               NaN                    2.015412                       NaN
# 58               NaN                         NaN                  9.312597
# 59               NaN                    1.981077                       NaN
# 60               NaN                         NaN                 78.784583
# 61               NaN                    2.443780                       NaN
# 62               NaN                         NaN                176.195498
# 63               NaN                    2.685439                       NaN
# 64               NaN                         NaN                  8.784380
# 65               NaN                    2.485840                       NaN
# 66               NaN                         NaN                 11.688873
# 67               NaN                    2.649322                       NaN
# 68               NaN                         NaN                  2.992152
# 69               NaN                    3.011734                       NaN
# 70               NaN                         NaN                  6.716013
# 71               NaN                    5.394422                       NaN
# 72               NaN                         NaN                 83.644602
# 73               NaN                    8.942826                       NaN
# 74               NaN                         NaN                 60.654220
# 75               NaN                    8.433597                       NaN
# 76               NaN                         NaN                 76.550438
# 77          0.126164                         NaN                       NaN
#
#     Recommended_trade
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# 35                NaN
# 36                NaN
# 37                NaN
# 38                NaN
# 39                NaN
# 40                NaN
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# 46                NaN
# 47                NaN
# 48                NaN
# 49                NaN
# 50                NaN
# 51                NaN
# 52                NaN
# 53                NaN
# 54                NaN
# 55                NaN
# 56                NaN
# 57                NaN
# 58                NaN
# 59                NaN
# 60                NaN
# 61                NaN
# 62                NaN
# 63                NaN
# 64                NaN
# 65                NaN
# 66                NaN
# 67                NaN
# 68                NaN
# 69                NaN
# 70                NaN
# 71                NaN
# 72                NaN
# 73                NaN
# 74                NaN
# 75                NaN
# 76                NaN
# 77           0.208873
